# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

import warnings
warnings.filterwarnings('ignore')

RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %% [markdown]
# # Loading Data:

# %%
# !pwd
# Out:
# /content

# %%
df = pd.read_csv("./drive/MyDrive/creditcard.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
sns.countplot(df.Class);

# %%
df.Class.value_counts(normalize= True)
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64

# %% [markdown]
# # Preprocessing

# %%
data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %% [markdown]
# # Model

# %% [markdown]
# Our Autoencoder uses 4 fully connected layers with 14, 7, 7 and 29 neurons respectively. The first two layers are used for our encoder, the last two go for the decoder. Additionally, L1 regularization will be used during training:

# %%
input_dim = X_train.shape[1]
encoding_dim = 14

# %%
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)

decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
nb_epoch = 100
batch_size = 32

autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.8033 - accuracy: 0.5989 - val_loss: 0.7838 - val_accuracy: 0.6605
# Epoch 2/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7447 - accuracy: 0.6688 - val_loss: 0.7644 - val_accuracy: 0.6710
# Epoch 3/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7258 - accuracy: 0.6792 - val_loss: 0.7528 - val_accuracy: 0.6833
# Epoch 4/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7185 - accuracy: 0.6871 - val_loss: 0.7471 - val_accuracy: 0.6873
# Epoch 5/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7132 - accuracy: 0.6913 - val_loss: 0.7435 - val_accuracy: 0.7016
# Epoch 6/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7096 - accuracy: 0.6984 - val_loss: 0.7437 - val_accuracy: 0.7059
# Epoch 7/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7061 - accuracy: 0.7045 - val_loss: 0.7389 - val_accuracy: 0.6994
# Epoch 8/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7040 - accuracy: 0.7084 - val_loss: 0.7346 - val_accuracy: 0.7103
# Epoch 9/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7029 - accuracy: 0.7107 - val_loss: 0.7335 - val_accuracy: 0.7135
# Epoch 10/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7013 - accuracy: 0.7113 - val_loss: 0.7337 - val_accuracy: 0.7123
# Epoch 11/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7007 - accuracy: 0.7118 - val_loss: 0.7350 - val_accuracy: 0.7025
# Epoch 12/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6999 - accuracy: 0.7138 - val_loss: 0.7328 - val_accuracy: 0.7144
# Epoch 13/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6999 - accuracy: 0.7123 - val_loss: 0.7344 - val_accuracy: 0.7138
# Epoch 14/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6989 - accuracy: 0.7133 - val_loss: 0.7346 - val_accuracy: 0.7071
# Epoch 15/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6987 - accuracy: 0.7131 - val_loss: 0.7320 - val_accuracy: 0.7174
# Epoch 16/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6983 - accuracy: 0.7137 - val_loss: 0.7328 - val_accuracy: 0.7091
# Epoch 17/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6980 - accuracy: 0.7137 - val_loss: 0.7336 - val_accuracy: 0.7155
# Epoch 18/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6976 - accuracy: 0.7152 - val_loss: 0.7318 - val_accuracy: 0.7155
# Epoch 19/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6988 - accuracy: 0.7133 - val_loss: 0.7310 - val_accuracy: 0.7156
# Epoch 20/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6967 - accuracy: 0.7148 - val_loss: 0.7300 - val_accuracy: 0.7191
# Epoch 21/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6971 - accuracy: 0.7147 - val_loss: 0.7319 - val_accuracy: 0.7164
# Epoch 22/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6968 - accuracy: 0.7143 - val_loss: 0.7325 - val_accuracy: 0.7101
# Epoch 23/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6962 - accuracy: 0.7134 - val_loss: 0.7297 - val_accuracy: 0.7137
# Epoch 24/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6965 - accuracy: 0.7128 - val_loss: 0.7300 - val_accuracy: 0.7123
# Epoch 25/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6962 - accuracy: 0.7132 - val_loss: 0.7306 - val_accuracy: 0.7093
# Epoch 26/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6958 - accuracy: 0.7124 - val_loss: 0.7296 - val_accuracy: 0.7129
# Epoch 27/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6956 - accuracy: 0.7116 - val_loss: 0.7303 - val_accuracy: 0.7089
# Epoch 28/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6951 - accuracy: 0.7112 - val_loss: 0.7297 - val_accuracy: 0.7104
# Epoch 29/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6959 - accuracy: 0.7102 - val_loss: 0.7304 - val_accuracy: 0.7145
# Epoch 30/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6950 - accuracy: 0.7105 - val_loss: 0.7290 - val_accuracy: 0.7081
# Epoch 31/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6947 - accuracy: 0.7103 - val_loss: 0.7295 - val_accuracy: 0.7121
# Epoch 32/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6947 - accuracy: 0.7104 - val_loss: 0.7277 - val_accuracy: 0.7109
# Epoch 33/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6952 - accuracy: 0.7095 - val_loss: 0.7281 - val_accuracy: 0.7107
# Epoch 34/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6946 - accuracy: 0.7091 - val_loss: 0.7302 - val_accuracy: 0.7128
# Epoch 35/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6941 - accuracy: 0.7100 - val_loss: 0.7276 - val_accuracy: 0.7142
# Epoch 36/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6938 - accuracy: 0.7103 - val_loss: 0.7272 - val_accuracy: 0.7095
# Epoch 37/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6941 - accuracy: 0.7099 - val_loss: 0.7275 - val_accuracy: 0.7120
# Epoch 38/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6938 - accuracy: 0.7124 - val_loss: 0.7267 - val_accuracy: 0.7165
# Epoch 39/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6934 - accuracy: 0.7115 - val_loss: 0.7273 - val_accuracy: 0.7152
# Epoch 40/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6935 - accuracy: 0.7125 - val_loss: 0.7262 - val_accuracy: 0.7141
# Epoch 41/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6931 - accuracy: 0.7117 - val_loss: 0.7282 - val_accuracy: 0.7039
# Epoch 42/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6929 - accuracy: 0.7107 - val_loss: 0.7331 - val_accuracy: 0.7154
# Epoch 43/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6934 - accuracy: 0.7100 - val_loss: 0.7266 - val_accuracy: 0.7161
# Epoch 44/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6926 - accuracy: 0.7114 - val_loss: 0.7264 - val_accuracy: 0.7102
# Epoch 45/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6933 - accuracy: 0.7100 - val_loss: 0.7264 - val_accuracy: 0.7134
# Epoch 46/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6925 - accuracy: 0.7111 - val_loss: 0.7252 - val_accuracy: 0.7173
# Epoch 47/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6924 - accuracy: 0.7104 - val_loss: 0.7268 - val_accuracy: 0.7118
# Epoch 48/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6928 - accuracy: 0.7112 - val_loss: 0.7267 - val_accuracy: 0.7127
# Epoch 49/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6923 - accuracy: 0.7112 - val_loss: 0.7260 - val_accuracy: 0.7081
# Epoch 50/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6921 - accuracy: 0.7118 - val_loss: 0.7264 - val_accuracy: 0.7156
# Epoch 51/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6924 - accuracy: 0.7113 - val_loss: 0.7255 - val_accuracy: 0.7131
# Epoch 52/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6920 - accuracy: 0.7123 - val_loss: 0.7262 - val_accuracy: 0.7054
# Epoch 53/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6921 - accuracy: 0.7115 - val_loss: 0.7261 - val_accuracy: 0.7083
# Epoch 54/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6920 - accuracy: 0.7122 - val_loss: 0.7262 - val_accuracy: 0.7137
# Epoch 55/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6920 - accuracy: 0.7130 - val_loss: 0.7252 - val_accuracy: 0.7135
# Epoch 56/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6917 - accuracy: 0.7119 - val_loss: 0.7258 - val_accuracy: 0.7118
# Epoch 57/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6912 - accuracy: 0.7122 - val_loss: 0.7299 - val_accuracy: 0.7129
# Epoch 58/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6911 - accuracy: 0.7110 - val_loss: 0.7259 - val_accuracy: 0.7125
# Epoch 59/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6910 - accuracy: 0.7085 - val_loss: 0.7256 - val_accuracy: 0.7054
# Epoch 60/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6905 - accuracy: 0.7079 - val_loss: 0.7247 - val_accuracy: 0.6984
# Epoch 61/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6912 - accuracy: 0.7077 - val_loss: 0.7291 - val_accuracy: 0.6841
# Epoch 62/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6905 - accuracy: 0.7063 - val_loss: 0.7253 - val_accuracy: 0.7114
# Epoch 63/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6908 - accuracy: 0.7069 - val_loss: 0.7263 - val_accuracy: 0.7131
# Epoch 64/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6901 - accuracy: 0.7061 - val_loss: 0.7249 - val_accuracy: 0.7110
# Epoch 65/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6904 - accuracy: 0.7069 - val_loss: 0.7262 - val_accuracy: 0.7069
# Epoch 66/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6905 - accuracy: 0.7065 - val_loss: 0.7252 - val_accuracy: 0.7083
# Epoch 67/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6904 - accuracy: 0.7060 - val_loss: 0.7253 - val_accuracy: 0.7112
# Epoch 68/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6902 - accuracy: 0.7061 - val_loss: 0.7314 - val_accuracy: 0.7045
# Epoch 69/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6902 - accuracy: 0.7061 - val_loss: 0.7256 - val_accuracy: 0.7042
# Epoch 70/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6901 - accuracy: 0.7056 - val_loss: 0.7265 - val_accuracy: 0.7086
# Epoch 71/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6898 - accuracy: 0.7062 - val_loss: 0.7259 - val_accuracy: 0.6990
# Epoch 72/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6902 - accuracy: 0.7060 - val_loss: 0.7281 - val_accuracy: 0.7088
# Epoch 73/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6899 - accuracy: 0.7061 - val_loss: 0.7254 - val_accuracy: 0.7131
# Epoch 74/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6898 - accuracy: 0.7058 - val_loss: 0.7252 - val_accuracy: 0.7085
# Epoch 75/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6900 - accuracy: 0.7056 - val_loss: 0.7282 - val_accuracy: 0.7084
# Epoch 76/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6902 - accuracy: 0.7045 - val_loss: 0.7247 - val_accuracy: 0.7060
# Epoch 77/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6896 - accuracy: 0.7052 - val_loss: 0.7284 - val_accuracy: 0.7112
# Epoch 78/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6900 - accuracy: 0.7051 - val_loss: 0.7296 - val_accuracy: 0.7015
# Epoch 79/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6902 - accuracy: 0.7047 - val_loss: 0.7244 - val_accuracy: 0.7059
# Epoch 80/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6899 - accuracy: 0.7054 - val_loss: 0.7271 - val_accuracy: 0.7000
# Epoch 81/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6899 - accuracy: 0.7069 - val_loss: 0.7272 - val_accuracy: 0.7077
# Epoch 82/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6895 - accuracy: 0.7063 - val_loss: 0.7313 - val_accuracy: 0.7028
# Epoch 83/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6893 - accuracy: 0.7058 - val_loss: 0.7248 - val_accuracy: 0.7045
# Epoch 84/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6894 - accuracy: 0.7062 - val_loss: 0.7268 - val_accuracy: 0.7076
# Epoch 85/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6896 - accuracy: 0.7058 - val_loss: 0.7270 - val_accuracy: 0.7062
# Epoch 86/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6895 - accuracy: 0.7058 - val_loss: 0.7256 - val_accuracy: 0.6966
# Epoch 87/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6896 - accuracy: 0.7051 - val_loss: 0.7249 - val_accuracy: 0.7113
# Epoch 88/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6892 - accuracy: 0.7057 - val_loss: 0.7253 - val_accuracy: 0.7038
# Epoch 89/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6894 - accuracy: 0.7065 - val_loss: 0.7259 - val_accuracy: 0.7137
# Epoch 90/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6892 - accuracy: 0.7048 - val_loss: 0.7258 - val_accuracy: 0.6923
# Epoch 91/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6892 - accuracy: 0.7045 - val_loss: 0.7265 - val_accuracy: 0.7007
# Epoch 92/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6892 - accuracy: 0.7049 - val_loss: 0.7302 - val_accuracy: 0.7015
# Epoch 93/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6889 - accuracy: 0.7060 - val_loss: 0.7278 - val_accuracy: 0.7060
# Epoch 94/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6891 - accuracy: 0.7056 - val_loss: 0.7263 - val_accuracy: 0.7123
# Epoch 95/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6889 - accuracy: 0.7050 - val_loss: 0.7245 - val_accuracy: 0.7152
# Epoch 96/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6891 - accuracy: 0.7061 - val_loss: 0.7228 - val_accuracy: 0.7096
# Epoch 97/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6893 - accuracy: 0.7056 - val_loss: 0.7235 - val_accuracy: 0.7118
# Epoch 98/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6893 - accuracy: 0.7060 - val_loss: 0.7229 - val_accuracy: 0.7121
# Epoch 99/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.6889 - accuracy: 0.7048 - val_loss: 0.7285 - val_accuracy: 0.7062
# Epoch 100/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.6889 - accuracy: 0.7046 - val_loss: 0.7255 - val_accuracy: 0.7088

# %%
autoencoder = load_model('model.h5')

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df
# Out:
#         reconstruction_error  true_class
# 43428              82.904264           1
# 49906               0.858745           0
# 29474               0.198475           0
# 276481              0.400193           0
# 278846              0.173745           0
# ...                      ...         ...
# 75723               0.709225           0
# 252263              0.196567           0
# 221246              0.545369           0
# 81910               0.183465           0
# 59490               1.602557           0
#
# [56962 rows x 2 columns]

# %%
# normal
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %%
# fraud
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %%
threshold = 10

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
